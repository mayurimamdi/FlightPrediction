# %% [markdown]
# ## import the libraries

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## add the path to the dataset

# %%
file_path="/Users/mayurimamdi/Downloads/Data_train.xlsx"

# %%
df_train=pd.read_excel(file_path)

# %% [markdown]
# ## analyse the data

# %%
df_train.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_train.shape
# Out:
# (10683, 11)

# %%
df_train['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df_train['Source'].value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df_train['Destination'].value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %% [markdown]
# ## check the test set

# %%
df_test=pd.read_excel("/Users/mayurimamdi/Downloads/Test_set.xlsx")

# %%
df_test.describe()
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count          2671            2671   2671        2671             2671
# unique           11              44      5           6              100
# top     Jet Airways       9/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq            897             144   1145        1145              624
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count      2671         2671     2671        2671            2671
# unique      199          704      320           5               6
# top       10:00        19:00   2h 50m      1 stop         No info
# freq         62          113      122        1431            2148

# %%
df_test.shape
# Out:
# (2671, 10)

# %% [markdown]
# ## merge them both

# %%
df=pd.concat([df_train, df_test], axis=0)

# %% [markdown]
# ## feature engineering

# %%
df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
df.drop('Date_of_Journey', axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price Date Month  Year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662.0    1    05  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0    9    06  2019
# 3         23:30   5h 25m      1 stop         No info   6218.0   12    05  2019
# 4         21:35   4h 45m      1 stop         No info  13302.0   01    03  2019

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  object
#  11  Month            13354 non-null  object
#  12  Year             13354 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.4+ MB

# %%
df['Date']=df['Date'].astype(int)

# %%
df['Month']=df['Month'].astype(int)

# %%
df['Year']=df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int64
#  11  Month            13354 non-null  int64
#  12  Year             13354 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (13354, 13)

# %%
df.drop(columns='Route', axis=1)
# Out:
#                 Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0                IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1             Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2           Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3                IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4                IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...                 ...       ...         ...      ...           ...      ...
# 2666          Air India   Kolkata    Banglore    20:30  20:25 07 Jun  23h 55m
# 2667             IndiGo   Kolkata    Banglore    14:20         16:55   2h 35m
# 2668        Jet Airways     Delhi      Cochin    21:50  04:25 07 Mar   6h 35m
# 2669          Air India     Delhi      Cochin    04:00         19:15  15h 15m
# 2670  Multiple carriers     Delhi      Cochin    04:55         19:15  14h 20m
#
# ...

# %%
df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
df['Arrival Hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival Min']=df['Arrival_Time'].str.split(':').str[1]

# %%
df['Arrival Hour'].head()
# Out:
# 0     1
# 1    13
# 2     4
# 3    23
# 4    21
# Name: Arrival Hour, dtype: int64

# %%
df['Arrival Min'].head()
# Out:
# 0    10 22 Mar
# 1           15
# 2    25 10 Jun
# 3           30
# 4           35
# Name: Arrival Min, dtype: object

# %% [markdown]
# I have to fix the mistakes that i made here, need to drop th enew columns that were made since its also adding the date as well

# %%
df.drop(columns='Arrival Hour', axis=1, inplace=True)

# %%
df.drop(columns='Arrival Min', axis=1, inplace= True)

# %%
df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
df['Arrival hour']=df['Arrival_Time'].str.split(':').str[0]

# %%
df['Arrival Min']=df['Arrival_Time'].str.split(':').str[1]

# %%
df['Arrival Min'].head()
# Out:
# 0    10 22 Mar
# 1           15
# 2    25 10 Jun
# 3           30
# 4           35
# Name: Arrival Min, dtype: object

# %%
df['Arrival hour']=df['Arrival hour'].astype(int)
df['Arrival Min']=df['Arrival Min'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 df['Arrival hour']=df['Arrival hour'].astype(int)
# ----> 2 df['Arrival Min']=df['Arrival Min'].astype(int)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %% [markdown]
# guess i made the same mistake.. need to sort out

# %%
df.drop(columns=['Arrival hour', 'Arrival Min'], axis=1, inplace = True)

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df['Arrival_Time'].head()
# Out:
# 0    01:10
# 1    13:15
# 2    04:25
# 3    23:30
# 4    21:35
# Name: Arrival_Time, dtype: object

# %% [markdown]
# now it is seem to be working

# %%
df['Arrival hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival Min']=df['Arrival_Time'].str.split(':').str[1]

# %%
df['Arrival hour'].head()
# Out:
# 0    01
# 1    13
# 2    04
# 3    23
# 4    21
# Name: Arrival hour, dtype: object

# %%
df['Arrival Min'].head()
# Out:
# 0    10
# 1    15
# 2    25
# 3    30
# 4    35
# Name: Arrival Min, dtype: object

# %%
df['Arrival hour']=df['Arrival hour'].astype(int)
df['Arrival Min']=df['Arrival Min'].astype(int)

# %%
df.drop(columns='Arrival_Time', axis=1, inplace=True)

# %% [markdown]
# Doing the same for Departure time

# %%
df['Dep hour']=df['Dep_Time'].str.split(':').str[0]

# %%
df['Dep min']=df['Dep_Time'].str.split(':').str[1]

# %%
df['Dep hour']=df['Dep hour'].astype(int)
df['Dep min']=df['Dep min'].astype(int)

# %%
df.drop(columns='Dep_Time', axis=1, inplace = True )

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
# 3      1 stop         No info   6218.0    12      5  2019            23
# 4      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival Min  Dep hour  Dep min
# 0           10        22       20
# 1           15         5       50
# ...

# %% [markdown]
# Lets start with total stops now

# %%
df['Total_Stops']=df['Total_Stops'].str.split(' ').str[0]

# %%
df['Total_Stops'].head()
# Out:
# 0    non-stop
# 1           2
# 2           2
# 3           1
# 4           1
# Name: Total_Stops, dtype: object

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0 })

# %%
df['Total_Stops'].head()
# Out:
# 0    0.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Total_Stops, dtype: float64

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Date  Month  Year  Arrival hour  \
# 0          0.0         No info   3897.0    24      3  2019             1
# 1          NaN         No info   7662.0     1      5  2019            13
# 2          NaN         No info  13882.0     9      6  2019             4
# 3          NaN         No info   6218.0    12      5  2019            23
# 4          NaN         No info  13302.0     1      3  2019            21
#
#    Arrival Min  Dep hour  Dep min
# 0           10        22       20
# 1           15         5       50
# ...

# %%
df['Total_Stops'] = df['Total_Stops'].map({
    'non-stop': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4': 4
})

# %%
df['Total_Stops'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['Total_Stops'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Total_Stops, dtype: float64

# %%
df['Total_Stops'].value_counts(dropna=False)
# Out:
# Total_Stops
# NaN    13354
# Name: count, dtype: int64

# %%
df['Total_Stops'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# I have messed up again n need to fix it

# %%
df['Total_Stops']=df_train['Total_Stops']

# %%
df['Total_Stops'].head()
# Out:
# 0    non-stop
# 1     2 stops
# 2     2 stops
# 3      1 stop
# 4      1 stop
# Name: Total_Stops, dtype: object

# %%
df['Total_Stops']=df['Total_Stops'].str.split(' ').str[0]

# %%
df['Total_Stops'].head()
# Out:
# 0    non-stop
# 1           2
# 2           2
# 3           1
# 4           1
# Name: Total_Stops, dtype: object

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2', '1', '3', nan, '4'], dtype=object)

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0, '1':1, '2':2, '3':3, '4': 4})

# %%
df['Total_Stops'].head()
# Out:
# 0    0.0
# 1    2.0
# 2    2.0
# 3    1.0
# 4    1.0
# Name: Total_Stops, dtype: float64

# %%
df['Total_Stops'].isnull().sum()
# Out:
# np.int64(1)

# %%
df.dropna(subset=['Total_Stops'], inplace=True)

# %%
df['Total_Stops'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Total_Stops']=df['Total_Stops'].astype(int)

# %%
df['Total_Stops'].head()
# Out:
# 0    0
# 1    2
# 2    2
# 3    1
# 4    1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# lets check duration now

# %%
df['Duration'].head()
# Out:
# 0    2h 50m
# 1    7h 25m
# 2       19h
# 3    5h 25m
# 4    4h 45m
# Name: Duration, dtype: object

# %%
df['Duration'].str.split(' ').str[0].str.split('h').str[0]
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration, Length: 13353, dtype: object

# %%
df['Duration hour']=df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['Duration'].str.split(' ').str[1].str.split('m').str[0]
# Out:
# 0        50
# 1        25
# 2       NaN
# 3        25
# 4        45
#        ...
# 2666     55
# 2667     35
# 2668     35
# 2669     15
# 2670     20
# Name: Duration, Length: 13353, dtype: object

# %%
df['Duration min']=df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df.drop(columns=['Duration','Route'], axis=1, inplace= True)

# %%
df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0       IndiGo  Banglore   New Delhi            0         No info   3897.0
# 1    Air India   Kolkata    Banglore            2         No info   7662.0
# 2  Jet Airways     Delhi      Cochin            2         No info  13882.0
# 3       IndiGo   Kolkata    Banglore            1         No info   6218.0
# 4       IndiGo  Banglore   New Delhi            1         No info  13302.0
#
#    Date  Month  Year  Arrival hour  Arrival Min  Dep hour  Dep min  \
# 0    24      3  2019             1           10        22       20
# 1     1      5  2019            13           15         5       50
# 2     9      6  2019             4           25         9       25
# 3    12      5  2019            23           30        18        5
# 4     1      3  2019            21           35        16       50
#
#   Duration hour Duration min
# 0             2           50
# 1             7           25
# ...

# %%
df['Duration min']=df['Duration min'].fillna(0)

# %%
df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0       IndiGo  Banglore   New Delhi            0         No info   3897.0
# 1    Air India   Kolkata    Banglore            2         No info   7662.0
# 2  Jet Airways     Delhi      Cochin            2         No info  13882.0
# 3       IndiGo   Kolkata    Banglore            1         No info   6218.0
# 4       IndiGo  Banglore   New Delhi            1         No info  13302.0
#
#    Date  Month  Year  Arrival hour  Arrival Min  Dep hour  Dep min  \
# 0    24      3  2019             1           10        22       20
# 1     1      5  2019            13           15         5       50
# 2     9      6  2019             4           25         9       25
# 3    12      5  2019            23           30        18        5
# 4     1      3  2019            21           35        16       50
#
#   Duration hour Duration min
# 0             2           50
# 1             7           25
# ...

# %% [markdown]
# ## chcek duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(246)
